# %%
import numpy as np
import pickle

# %%
X_a = np.array([
[[0.30,-0.13,0.89],[-0.04,0.04,1.00]],
[[0.18,-0.02,0.74],[0.04,-0.14,0.89]],
[[-0.17,-0.04,1.18],[0.15,0.01,0.97]],
[[-0.11,-0.14,1.00],[0.08,-0.01,0.75]],
[[0.19,0.13,0.82],[-0.19,0.48,0.50]],
[[0.04,-0.01,1.16],[0.25,0.11,0.97]],
[[-0.12,-0.03,1.24],[-0.17,0.02,1.10]],
[[0.13,-0.06,0.96],[-0.17,-0.06,1.05]],
[[-0.19,-0.02,1.00],[0.04,-0.24,0.72]],
[[-0.03,0.01,0.98],[-0.17,0.07,1.14]],
[[0.10,0.04,1.02],[-0.21,-0.06,0.96]],
[[0.16,0.02,0.87],[-0.08,0.10,1.06]],
[[-0.25,0.02,1.13],[0.08,0.05,0.86]],
[[-0.11,0.09,1.12],[-0.19,0.01,1.09]],
[[0.11,0.10,0.98],[-0.23,0.11,1.16]],
[[-0.17,0.12,1.17],[0.14,0.04,0.96]],
[[-0.18,0.21,1.11],[-0.14,0.13,1.04]],
[[0.12,0.02,0.93],[-0.17,0.14,0.91]],
[[0.11,0.02,0.86],[-0.00,0.05,0.84]],
[[-0.16,0.09,0.99],[0.12,0.12,0.96]],
[[-0.05,0.16,1.07],[-0.14,0.16,1.08]],
[[0.09,0.10,0.97],[-0.19,0.04,1.07]],
[[-0.18,0.08,1.20],[0.13,0.16,0.82]],
[[-0.20,0.00,0.98],[-0.02,0.09,0.93]],
[[0.08,0.19,0.84],[-0.14,-0.04,0.95]],
[[0.17,0.19,0.73],[0.01,0.14,0.86]],
[[-0.20,-0.05,0.97],[0.15,0.10,0.92]],
[[-0.13,0.03,1.11],[-0.17,-0.03,0.88]],
[[0.17,0.09,0.94],[-0.19,-0.02,1.10]],
[[-0.10,-0.00,1.15],[0.18,-0.06,0.93]],
[[-0.13,-0.00,0.95],[0.14,0.01,0.95]],
[[-0.15,-0.02,1.28],[-0.19,-0.06,1.15]],
[[0.06,-0.04,0.96],[-0.20,-0.10,1.12]],
[[-0.16,-0.00,1.08],[0.23,0.03,0.92]],
[[0.01,-0.01,1.03],[-0.17,-0.18,0.97]],
[[0.12,-0.06,1.04],[-0.29,-0.08,0.93]],
[[0.06,0.04,0.95],[-0.21,-0.07,1.02]],
[[-0.29,0.02,1.25],[0.14,-0.18,0.84]],
[[0.03,0.00,0.77],[-0.31,-0.17,0.96]],
[[0.13,-0.01,0.68],[-0.08,-0.01,0.84]],
[[-0.30,-0.18,0.89],[0.03,-0.14,0.83]],
[[0.06,-0.03,0.73],[-0.29,-0.21,0.94]],
[[-0.47,0.15,0.84],[0.20,-0.17,1.03]],
[[-0.57,-0.48,1.03],[-0.50,0.02,1.25]],
[[0.27,-0.13,0.92],[-0.52,-0.29,0.80]],
[[0.02,0.02,0.79],[-0.10,-0.09,0.98]],
[[-0.44,-0.35,0.89],[0.26,-0.27,0.97]],
[[-0.44,0.08,0.92],[0.26,-0.17,0.50]],
[[0.41,-0.14,0.71],[-0.72,-0.05,0.72]],
[[-0.18,-0.29,1.12],[-0.33,-0.40,0.85]],
[[0.55,-0.27,0.58],[-0.21,-0.09,1.13]],
[[-0.44,-0.59,0.98],[0.10,-0.26,0.68]],
[[-0.43,0.13,1.01],[0.39,-0.05,0.66]],
[[-0.47,-0.21,0.89],[0.13,-0.01,0.95]],
[[-0.10,0.03,0.91],[-0.38,-0.19,1.04]],
[[0.45,-0.13,0.90],[-0.61,0.13,0.86]],
[[-0.31,-0.44,0.83],[0.35,-0.21,0.74]],
[[-0.46,0.14,0.86],[0.14,-0.25,0.87]],
])

# %%
X_a[...,2]
# Out:
# array([[0.89, 1.  ],
#        [0.74, 0.89],
#        [1.18, 0.97],
#        [1.  , 0.75],
#        [0.82, 0.5 ],
#        [1.16, 0.97],
#        [1.24, 1.1 ],
#        [0.96, 1.05],
#        [1.  , 0.72],
#        [0.98, 1.14],
#        [1.02, 0.96],
#        [0.87, 1.06],
#        [1.13, 0.86],
#        [1.12, 1.09],
#        [0.98, 1.16],
#        [1.17, 0.96],
#        [1.11, 1.04],
#        [0.93, 0.91],
#        [0.86, 0.84],
#        [0.99, 0.96],
#        [1.07, 1.08],
#        [0.97, 1.07],
#        [1.2 , 0.82],
#        [0.98, 0.93],
#        [0.84, 0.95],
#        [0.73, 0.86],
#        [0.97, 0.92],
#        [1.11, 0.88],
#        [0.94, 1.1 ],
#        [1.15, 0.93],
#        [0.95, 0.95],
#        [1.28, 1.15],
#        [0.96, 1.12],
#        [1.08, 0.92],
#        [1.03, 0.97],
#        [1.04, 0.93],
#        [0.95, 1.02],
#        [1.25, 0.84],
#        [0.77, 0.96],
#        [0.68, 0.84],
#        [0.89, 0.83],
#        [0.73, 0.94],
#        [0.68, 0.77],
# ...

# %%
X = np.concatenate((X_no, X_yes, X_ok, X_start, X_stop), axis=0)

# %%
y = ["no" for x in range(len(X_no))] + ["yes" for x in range(len(X_yes))] + ["ok" for x in range(len(X_ok))] + ["start" for x in range(len(X_ok))] + ["stop" for x in range(len(X_yes))]

# %%
y = np.array(y)

# %%
with open('data/X.pkl', 'wb') as f:
    pickle.dump(X, f)

# %%
with open('data/y.pkl', 'wb') as f:
    pickle.dump(y, f)
