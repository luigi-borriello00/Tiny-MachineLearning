# %%
import numpy as np
import pandas as pd
import sklearn.metrics as metrics

# %%
labels = ["O", "I", "U", "E", "A", "B", "D", "G", "L", "M", "N", "P", "Q", "V", "W"]

# %%
y_real = np.array([5,  4, 11, 14, 13, 10, 14,  0,  3, 14,  7,  5,  4,  3,  4,  6,  1,
        2,  1,  5,  2, 11, 13,  6,  7, 13, 11,  6, 12,  8,  5,  5,  0,  2,
       14, 14,  8, 14,  9,  8,  3,  9,  3,  8,  7,  8, 11,  7,  8,  3, 12,
        2, 10, 13, 11,  6,  4,  6,  2,  8,  2,  6,  1,  3,  9, 13, 11,  7,
        7,  3,  7,  5,  1, 11,  6,  8, 13,  4,  1,  0,  1,  7, 13, 12,  0,
        2, 10, 12, 14,  4,  0,  5,  0, 10, 10, 10,  0,  7, 10,  1,  1,  5,
        0,  3, 12,  9,  6, 14, 12,  2,  6, 11,  5,  7,  2,  0,  2,  0,  2,
        3,  9,  5, 13,  2, 11,  6,  1,  0, 11,  0,  0, 14,  6, 10,  1,  0,
        2,  4, 14, 11, 12, 14,  1,  9, 11,  8,  0,  4,  7,  3, 14, 11,  5,
        5,  3, 10, 11,  0, 11,  6,  1, 13,  3,  4,  6,  2,  1,  4,  3,  9,
        9,  6,  8,  7,  9, 12,  3, 12,  5,  1,  0,  0, 13, 14,  3,  9, 13,
        0,  8, 10,  8, 10,  2,  9,  1,  4, 14,  3, 13,  4,  1,  4,  3, 12,
       14,  5, 12, 12,  8,  9,  6, 11,  4,  4,  5,  7, 14, 11, 11, 10,  4,
        6, 14, 12, 12,  2,  8, 13,  7,  6, 13,  7,  8,  7,  9,  8, 12, 10,
        7, 10,  7, 10,  7,  6, 14,  0, 10,  8,  8,  9,  1,  9, 12, 12,  4,
       13, 14,  9, 11,  2, 14, 10, 10, 13, 13,  5, 13,  8, 10,  5, 10,  1,
        7,  4,  1,  2,  9,  8,  9,  4, 13,  6, 11,  6, 12,  4,  3, 13,  9,
        3,  2,  3,  1, 12,  2,  9,  5, 12,  5,  5])

# %%
prediction_nn = np.array([5, 4, 11, 14, 13, 10, 14, 0, 3, 14, 7, 5, 4, 3, 4, 6, 1, 2, 1, 5, 2, 11, 13, 6, 7, 13, 11, 6, 12, 8, 5, 5, 0, 10, 13, 14, 8, 14, 9, 8, 3, 9, 3, 8, 7, 8, 11, 7, 8, 3, 12, 2, 10, 13, 11, 6, 0, 6, 2, 8, 2, 5, 1, 3, 3, 13, 11, 7, 7, 3, 7, 5, 1, 11, 6, 8, 13, 4, 1, 0, 1, 7, 14, 12, 0, 2, 10, 12, 14, 4, 0, 5, 0, 10, 10, 10, 0, 7, 10, 1, 1, 5, 0, 3, 12, 9, 6, 14, 12, 2, 6, 11, 5, 7, 2, 0, 2, 0, 2, 3, 9, 14, 13, 
 12, 14, 4, 0, 5, 0, 10, 10, 10, 0, 7, 10, 1, 1, 5, 0, 3, 12, 3, 6, 14, 12, 2, 6, 0, 3, 13, 12, 0, 2, 0, 2, 3, 9, 3, 13, 2, 11, 6, 1, 0, 11, 0, 12, 14, 6, 10, 1, 0, 2, 14, 13, 11, 12, 14, 1, 3, 11, 7, 0, 14, 7, 3, 12, 11, 5, 5, 3, 10, 11, 0, 11, 6, 1, 13, 0, 4, 6, 2, 1, 4, 3, 9, 3, 6, 8, 8, 9, 5, 3, 12, 5, 1, 0, 0, 13, 13, 3, 9, 14, 0, 8, 10, 8, 10, 2, 9, 3, 4, 14, 3, 13, 4, 1, 4, 3, 12, 14, 5, 12, 12, 8, 9, 6, 11, 4, 14, 5, 13, 4, 11, 11, 10, 4, 6, 14, 0, 0, 2, 8, 13, 7, 6, 13, 5, 8, 7, 3, 8, 12, 11, 7, 10, 7, 10, 8, 6, 14, 0, 10, 8, 8, 9, 1, 9, 12, 12, 4, 13, 14, 6, 11, 2, 14, 10, 10, 14, 13, 5, 8, 8, 10, 5, 10, 1, 7, 4, 1, 2, 9, 8, 9, 4, 13, 6, 11, 6, 1, 4, 9, 13, 3, 14, 1, 3, 1, 12, 2, 9, 5, 14, 5, 5,])

# %%
pred = []
uniques = np.unique(y_real)
pred.append(("NN",prediction_nn))
pred.append(("RF",prediction_rf))
pred.append(("CART",prediction_cart))
pred.append(("SVC",prediction_svc))
pred.append(("GNB",prediction_gnb))
pred.append(("LR",prediction_lr))

# %%
def classification_report_csv(report, model_name):
    report_data = []
    lines = report.split('\n')
    index = 0
    row = lines[-4].split('    ')
    accuracy = row[-2]
    for line in lines[2:-5]:
        row = {}
        row_data = line.split('      ')
        row['class'] = labels[index]
        row['precision'] = float(row_data[2]) 
        row['recall'] = float(row_data[3]) 
        row['f1_score'] = float(row_data[4])
        row['accuracy'] = accuracy
        report_data.append(row)
        index += 1
    dataframe = pd.DataFrame.from_dict(report_data)
    dataframe.to_csv( 'evaluations/'+'classification_report' + model_name +  '.csv', index = False)

# %%
for name, preds in pred:
    print(name + ": \n")
    report = metrics.classification_report(y_real, preds)
    print(report)
    classification_report_csv(report, name)
    print("-----------------------")
# Out:
# NN:
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       0.91      1.00      0.95        20
#            2       1.00      0.85      0.92        20
#            3       0.76      0.95      0.84        20
#            4       0.95      0.90      0.92        20
#            5       0.95      0.95      0.95        20
#            6       0.95      0.90      0.92        20
#            7       1.00      0.90      0.95        20
#            8       0.91      1.00      0.95        20
#            9       1.00      0.65      0.79        20
#           10       0.95      0.95      0.95        20
#           11       0.91      1.00      0.95        20
#           12       0.95      1.00      0.98        20
#           13       0.90      0.90      0.90        20
#           14       0.81      0.85      0.83        20
#
#     accuracy                           0.92       300
# ...
